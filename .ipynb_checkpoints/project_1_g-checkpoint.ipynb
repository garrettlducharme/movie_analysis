# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
from data_cleaner import clean_movie_budgets
from data_cleaner import clean_tmdb_movies
from data_cleaner import join_dataframes

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#movie_gross_df = pd.read_csv('data/bom.movie_gross.csv')
# name_df = pd.read_csv('data/imdb.name.basics.csv')
# title_akas_df = pd.read_csv('data/imdb.title.akas.csv')
# title_basics_df = pd.read_csv('data/imdb.title.basics.csv')
# title_crew_df = pd.read_csv('data/imdb.title.crew.csv')
# title_principals_df = pd.read_csv('data/imdb.title.principals.csv')
# title_ratings_df = pd.read_csv('data/imdb.title.ratings.csv')
# rt_movie_info_df = pd.read_csv('data/rt.movie_info.tsv', delimiter='\t')
# rt_reviews_df = pd.read_csv('data/rt.reviews.tsv', encoding='windows-1254', delimiter='\t')
tmdb_movies_df = pd.read_csv('data/tmdb.movies.csv')
tn_budgets_df = pd.read_csv('data/tn.movie_budgets.csv')

# %%
clean_tmdb_movies_df = clean_tmdb_movies(tmdb_movies_df)
clean_tn_budgets_df = clean_movie_budgets(tn_budgets_df)

# %%
joined_movies_df = join_dataframes(clean_tmdb_movies_df, clean_tn_budgets_df)

# %%
joined_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 715 entries, 10 Cloverfield Lane to Zootopia
# Data columns (total 10 columns):
# genre_ids                     715 non-null object
# popularity                    715 non-null float64
# vote_average                  715 non-null float64
# vote_count                    715 non-null int64
# production_budget ($M)        715 non-null float64
# domestic_gross ($M)           715 non-null float64
# worldwide_gross ($M)          715 non-null float64
# domestic_production_ratio     715 non-null float64
# worldwide_production_ratio    715 non-null float64
# worldwide_domestic_ratio      715 non-null float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 61.4+ KB

# %%
def plot_genre_stats(col_name):
    gneres = None
    col_name_dict = {}
    genre_count_dict = {}
    
    for i, genres in enumerate(joined_movies_df.genre_ids):
        for genre in genres:
            if genre not in col_name_dict.keys():
                col_name_dict[genre] = joined_movies_df[col_name].iloc[i]
                genre_count_dict[genre] = 1
            else:
                col_name_dict[genre] += joined_movies_df[col_name].iloc[i]
                genre_count_dict[genre] += 1
                
    avg_stats = {k: col_name_dict[k] / genre_count_dict[k] for k \
               in col_name_dict if k in genre_count_dict}
    
    sorted_stats = sorted(avg_stats.items(), key = lambda kv: kv[1])
    genres, stats = zip(*sorted_stats)
    
    plt.figure(figsize = (12,8))
    plt.barh(range(len(avg_stats)), stats, align = 'center')
    plt.yticks(range(len(avg_stats)), genres);
    plt.title(f'Avg {col_name} for All Movies by Genre')
    plt.ylabel('Genre')
    plt.xlabel(f'Average {col_name}')

# %%
plot_genre_stats('worldwide_gross ($M)')

# %%
plot_genre_stats('domestic_gross ($M)')

# %%
plot_genre_stats('worldwide_production_ratio')

# %%
plot_genre_stats('domestic_production_ratio')

# %%
#Not correct. Needs to have vote count filtered
plot_genre_stats('vote_average')

# %%
joined_movies_df['production_budget ($M)'].describe()
# Out:
# count    717.000000
# mean      45.318828
# std       55.423572
# min        0.000000
# 25%       10.000000
# 50%       25.000000
# 75%       55.000000
# max      330.600000
# Name: production_budget ($M), dtype: float64

# %%
# tmdb_movies_df.sort_values('popularity', ascending = False).head()
popularity_dict = {}
genre_count_dict = {}

for i, genres in enumerate(joined_movies_df.genre_ids):
    for genre in genres:
        if genre not in popularity_dict.keys():
            popularity_dict[genre] = joined_movies_df.popularity.iloc[i]
            genre_count_dict[genre] = 1
        else:
            popularity_dict[genre] += joined_movies_df.popularity.iloc[i]
            genre_count_dict[genre] += 1

# %%
avg_pop = {k: popularity_dict[k] / genre_count_dict[k] for k \
           in popularity_dict if k in genre_count_dict}

sorted_avgs = sorted(avg_pop.items(), key = lambda kv: kv[1])

genres, pops = zip(*sorted_avgs)

print(genres)
print(pops)
# Out:
# ('none', 'TV-movie', 'documentary', 'music', 'horror', 'drama', 'mystery', 'comedy', 'crime', 'thriller', 'family', 'history', 'war', 'animated', 'western', 'fantasy', 'sci-fi', 'action', 'adventure')
# (0.648, 2.2640000000000002, 6.047461538461538, 11.408280000000001, 12.595100000000004, 12.63035294117647, 12.638653061224487, 12.986526501766795, 14.555924050632916, 15.145479289940821, 15.99971111111112, 16.18769565217391, 16.9886, 17.426964285714288, 17.6048, 20.43519444444444, 20.630211764705876, 21.013553459119485, 21.882694214876036)

# %%
plt.figure(figsize = (12,8))
plt.barh(range(len(avg_pop)), pops, align = 'center')
plt.yticks(range(len(avg_pop)), genres);
plt.title('Avg Popularity for All Movies by Genre')
plt.ylabel('Genre')
plt.xlabel('Average Popularity')
# plt.savefig('avg_pop_all_movies.png')
# Out:
# Text(0.5, 0, 'Average Popularity')

# %%
clean_tmdb_movies_df.head()
# Out:
#    Unnamed: 0                               genre_ids  popularity  \
# 0           0            [adventure, fantasy, family]      33.533
# 1           1  [fantasy, adventure, animated, family]      28.734
# 2           2             [adventure, action, sci-fi]      28.515
# 3           3              [animated, comedy, family]      28.005
# 4           4             [action, sci-fi, adventure]      27.920
#
#   release_date                                         title  vote_average  \
# 0   2010-11-19  Harry Potter and the Deathly Hallows: Part 1           7.7
# 1   2010-03-26                      How to Train Your Dragon           7.7
# 2   2010-05-07                                    Iron Man 2           6.8
# 3   1995-11-22                                     Toy Story           7.9
# 4   2010-07-16                                     Inception           8.3
#
#    vote_count
# 0       10788
# 1        7610
# 2       12368
# 3       10174
# 4       22186

# %%
clean_tn_budgets_df.head()
# Out:
#                                              id  production_budget ($M)  \
# title
# Pirates of the Caribbean: On Stranger Tides   2                   410.6
# Dark Phoenix                                  3                   350.0
# Avengers: Age of Ultron                       4                   330.6
# Star Wars Ep. VIII: The Last Jedi             5                   317.0
# Star Wars Ep. VII: The Force Awakens          6                   306.0
#
#                                              domestic_gross ($M)  \
# title
# Pirates of the Caribbean: On Stranger Tides                241.1
# Dark Phoenix                                                42.8
# Avengers: Age of Ultron                                    459.0
# Star Wars Ep. VIII: The Last Jedi                          620.2
# Star Wars Ep. VII: The Force Awakens                       936.7
#
#                                              worldwide_gross ($M)  \
# title
# Pirates of the Caribbean: On Stranger Tides                1045.7
# Dark Phoenix                                                149.8
# Avengers: Age of Ultron                                    1403.0
# Star Wars Ep. VIII: The Last Jedi                          1316.7
# Star Wars Ep. VII: The Force Awakens                       2053.3
#
#                                              domestic_production_ratio  \
# title
# Pirates of the Caribbean: On Stranger Tides                       0.59
# Dark Phoenix                                                      0.12
# Avengers: Age of Ultron                                           1.39
# Star Wars Ep. VIII: The Last Jedi                                 1.96
# Star Wars Ep. VII: The Force Awakens                              3.06
#
#                                              worldwide_production_ratio  \
# title
# Pirates of the Caribbean: On Stranger Tides                        2.55
# Dark Phoenix                                                       0.43
# Avengers: Age of Ultron                                            4.24
# Star Wars Ep. VIII: The Last Jedi                                  4.15
# Star Wars Ep. VII: The Force Awakens                               6.71
#
#                                              worldwide_domestic_ratio
# title
# Pirates of the Caribbean: On Stranger Tides                      4.34
# Dark Phoenix                                                     3.50
# Avengers: Age of Ultron                                          3.06
# Star Wars Ep. VIII: The Last Jedi                                2.12
# Star Wars Ep. VII: The Force Awakens                             2.19
