# %% [markdown]
# # Introduction
#
# # Determining Important Factors For Producing Successful Movies Today
#
#
# In this notebook we will explore some of the characteristics of the most successful recent movies

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Main Questions
#
# * What genres are best for driving revenue?
#
# * What is the effect of budget on revenue?
#
# * What steps can we take to opitmize profitability?

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # First Steps
#
# Before we can properly begin our exploration of information from movies, we need to have a good framework
#
# The first step we took was to make sure our notebook was able to properly handle all capabilities we needed for the project
#
# To do this we borrowed from public functions and created our own designed specifically to analyze movies
#
# After this we introduced our two datasets and began to take the next steps

# %% [markdown]
# # Connecting And Cleaning Data
#
# We began with two sets of data; one with 6,000 entries and one with 26,000 entries
#
# Therefore, our next step focussed on connecting data in a logical manner into one central location
#
# After centralizing the information we filtered out information we weren't focussing on
#
# This process included: focussing on newer movies released in English, looking at top performing movies, ignoring reboots, looking at movies that received large numbers df ratings, and movies that outearned their budget
#
# We also added information to indicate profitability metrics
#
# Finally We Determined That Wanted To Place An Emphasis On Worldwide Revenue As Opposed To Just Domestic

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # The effect of region

# %% [markdown]
# ![](img/5.png)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Exploring Cause And Effect
#
# We now have a managable data set which will now be used to explore three possible correlations

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Movie Ratings
#
# The first analysis we did placed a focus on the effect of movie ratings on revenue
#
# To do this we created a scatter plot aimed at demonstrating the pressence of correlation
#
# While initially we believed there was a high correlation, we later found that movie ratings mattered the most to revenue for action movies based on multiple scatter plots, but mainly the one below

# %% [markdown]
# ![](img/4.png)

# %% [markdown]
# ![](img/1.png)

# %% [markdown]
# # Movie Genres
#
# After determining the above correlation we wanted to see which genres deserved most attention from studios
#
# To do this we looked at genre popularity, revenue generation, and profitability
#
# We found that the most important movies to look at were action, sci-fi, fantasy, and adventure movies

# %%
plot_genre_counts(movies_top_100_df)
# Out:
# [('music', 2), ('history', 4), ('war', 5), ('horror', 7), ('mystery', 11), ('crime', 11), ('animated', 14), ('family', 18), ('comedy', 23), ('thriller', 25), ('fantasy', 26), ('sci-fi', 35), ('drama', 37), ('adventure', 46), ('action', 55)]

# %%
plot_genre_stats(movies_top_200_df, 'domestic_gross ($M)')
# Out:
# {'adventure': 73, 'action': 94, 'fantasy': 37, 'thriller': 62, 'sci-fi': 53, 'drama': 66, 'comedy': 54, 'music': 3, 'mystery': 30, 'family': 36, 'animated': 27, 'crime': 27, 'history': 6, 'war': 7, 'horror': 21, 'western': 3}

# %%
plot_genre_stats('domestic_production_ratio')

# %%
#Not correct. Needs to have vote count filtered
plot_genre_stats('vote_average')

# %%
plot_genre_stats('popularity')

# %% [markdown]
# # Improving Revenue And Profitability
#
# We have shown what genres deserve most focus from studios
#
# Our next questions addressed the effects of budget on revenue and profitability
#
# Our findings showed that investing more money will improve revenue, but profitability is harder to control
#
# This also suggests that at a certain point, overinvesting will quickly diminish profitability

# %% [markdown]
# ![](img/2.png)
#
# <br></br>
#
# ![](img/3.png)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Conclusions
#
# 1. Action, sci-fi, adventure, and fantasy movies should be the focus of big-budget studios
# <br></br>
# 2. Production should be ramped up to drive revenue, placing a focus on the volume of movies produced
# <br></br>
# 3. Smaller budget studios may want to focus on other genres, such as horror and thriller which may be more profitable
# <br></br>
# 4. Movie ratings are most important at driving revenue for action movies
# <br></br>
